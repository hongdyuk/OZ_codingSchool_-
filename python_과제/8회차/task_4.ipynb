# %% [markdown]
# [문제]
#
# 'Employee' 클래스를 선언하세요.
#
# 이 클래스는 월급인상률을 의미하는 클래스 변수로 'raise_amount'를 갖고 있으며, 기본값은 1.04입니다. 다음 급여는 기본 급여에 월급인상률을 곱한 값으로 결정합니다.
#
# 또한, 각 직원의 이름(name)과 급여(salary)를 속성으로 가지며, 'apply_raise' 메소드를 통해 급여에 'raise_amount'를 적용할 수 있어야 합니다.
#
# 'Employee' 클래스의 객체 두 개를 생성하고, 한 객체에만 'raise_amount'를 변경한 후, 두 객체의 급여를 증가시켜보세요.<br>
# 그리고 각 객체의 새로운 급여를 출력하세요.

# %%
class Employee():
    raise_amount = 1.04
    def __init__(self, name: str, salary: int) -> None:
        self.name = name
        self.salary = salary

    def apply_raise(self):
        self.salary = int(self.salary * self.raise_amount)
        print(f'{self.name}님의 월급이 {self.raise_amount}%로 인상되어 {self.salary}만원 받게 되었습니다.')

emp1 = Employee('홀길동', 200)
emp2 = Employee('김코딩', 180)

emp1.raise_amount = 1.05
emp1.apply_raise()

emp2.raise_amount = 1.03
emp2.apply_raise()

print(emp1.apply_raise)
print(emp2.apply_raise)
# Out:
# 홀길동님의 월급이 1.05%로 인상되어 210만원 받게 되었습니다.
# 김코딩님의 월급이 1.03%로 인상되어 185만원 받게 되었습니다.
# <bound method Employee.apply_raise of <__main__.Employee object at 0x106a5f770>>
# <bound method Employee.apply_raise of <__main__.Employee object at 0x106895580>>
