# %% [markdown]
# [문제]
#
# 'Account' 클래스를 작성하세요.
#
# 이 클래스는 소유자(owner)와 잔액(balance)을 속성으로 가지며, 잔액은 프라이빗 변수로 선언합니다.
#
# 'deposit'와 'withdraw' 두 개의 메소드를 통해 잔액을 조작할 수 있도록 하세요.
#
# 이 때, 잔액은 음수가 될 수 없도록 체크해야 합니다. 'Account' 객체를 생성하고,<br>
# 입금 및 출금 작업을 시뮬레이션한 후, 최종 잔액을 출력하세요.

# %%
class Account:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.__balance = balance

    def deposit(self, amount): # 보증금
        if amount > 0:
            self.__balance += amount
            return f'입금을 완료했습니다. 현재 잔액은 {self.__balance}원 입니다.'
        else:
            return '입금이 불가합니다.'

    def withdraw(self, amount): # 철회
        if self.__balance >= amount > 0:
            self.__balance -= amount
            return f'{amount}원 출금을 완료했습니다. 현재 잔액은 {self.__balance}원 입니다.'
        else:
            return '출금이 불가합니다.'

    def current_balance(self):
        return self.__balance

act = Account('홍길동')


act.deposit(500)
act.withdraw(250)
# Out:
# '250원 출금을 완료했습니다. 현재 잔액은 250원 입니다.'
