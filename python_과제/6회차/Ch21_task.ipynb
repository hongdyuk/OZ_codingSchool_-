# %% [markdown]
# 사용자로부터 이름과 나이를 입력 받아, "안녕하세요, [이름]님! 당신은 [나이]살입니다."라고 출력하는 함수 greet_user를 작성하세요.

# %%
def greet_user(이름,나이): # greet_user함수를 만들어 이름과 나이를 입력받는다.
    print(f'사용자님의 이름은 {이름}님이며, 나이는 {나이}살 입니다.')
    # 함수를 실행하였을 때 print()함수가 출력된다. 

이름, 나이 = input('사용자의 이름과 나이를 입력해주세요(ex. 김코딩,30)').split(',')
greet_user(이름,나이)
# Out:
# 사용자님의 이름은 김코딩님이며, 나이는 23살 입니다.
