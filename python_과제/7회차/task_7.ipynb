# %% [markdown]
# 함수 실행 시간을 측정하는 데코레이터 timer_decorator를 작성하세요.
#
# 임의의 함수가 실행되는 시간을 측정하여 "함수 실행 시간: x.xx초" 형태로 출력하세요.

# %%
import time

start_time = time.time()

def fun(function):
    def wrapper(*args, **kwargs):
        function(*args, **kwargs)
        end_time = time.time()
        print(f'프로그램이 운영된 시간은 {end_time - start_time:.4f}초 입니다.')
    return wrapper

@fun
def time_check(a,b):
    result = a + b
    print(f'계산결과는 {result} 입니다.')

time_check(1,2)
# Out:
# 계산결과는 3 입니다.
# 프로그램이 운영된 시간은 0.0002초 입니다.
